# %% [markdown]
# # Word Cloud

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from PIL import Image
import wikipedia

# %%
title=str(input("Enter the title: "))
keyword=wikipedia.search(title)
page=wikipedia.page(keyword)
content=page.content

stopwords=set(STOPWORDS)
wordcloud=WordCloud(background_color='white',max_words=300,stopwords=stopwords,width=1600,height=800)
plt.figure(figsize=(10,10),facecolor="none")

wordcloud.generate(content)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# Enter the title: twitter

# %%
import os

os.chdir(r"C:\Users\vishal tupe\Desktop\data science practical\Data Science\world cloud")

# %%
wordcloud.to_file("cricket1.jpg")

# %%
mask=np.array(Image.open("C:\\Users\\vishal tupe\\Desktop\\data science practical\\Data Science\\world cloud\\761_twitter.jpg"))

# %%
wordcloud=WordCloud(mask=mask,background_color='white')

# %% [markdown]
# # Word Cloud 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
stopwords=set(STOPWORDS)

# %%
mask=np.array(Image.open("C:\\Users\\vishal tupe\\Desktop\\data science practical\\Data Science\\world cloud\\761_twitter.jpg"))

# %%
data="politics hugely important domain world profound impact functioning well policies governments . politics effect types government including democratic , autocratic , monarchical , theocratic others . government responsible making decisions different matters public interest , issuing orders public health , directing citizens towards development growth , performing wide range related functions . numerous definitions politics means . politics described disagreement various groups like . one broad definitions politics , widely agreed , art governance . government entity legal authority regulating people ’ actions . word politics usually used defining countries governed governments make rules laws . defining laws regulations tell people one ways government leads people . regulations laws enacted government ensuring order protection society . beyond laws , government might also regulate citizens functioning country ways . countries specific groups political parties expressing views policies . political parties form consensus common policies path take communicating ideas policies people . parties support legislative bills reforms candidates based agenda agreed upon members . election usually contested fought opposite political parties different spectrum . one conventional explanations politics refers politics conducted within system checks balances avoiding misuse political power . several institutions exist within governing system include legislative body responsible making laws , executive body imposes , judiciary interprets thus providing powerful well-rounded political spectrum . want study detail politics various concepts applications essay english refer vedantu website app . vedantu leading learning platform wide range learning resources , tutorials , solutions , reference notes , sample questions papers solutions students different branches . short politics essay english politics , general , platform people create , maintain , change laws govern lives . result , conflict collaboration inextricably connected politics . one hand , presence conflicting views , competing expectations , competing needs , competing interests expected result conflict rules people live . politics fascinating everyone different perspective life rules . differing opinions live . money go ? best way disperse power help powerless ? better society built collaboration conflict ? forth . also talk disputes resolved . best way make decisions group ? conditions say ? much say person decisions ? list goes . , according aristotle , made politics `` master science , '' described `` action human beings strive better lives build contribute good society . '' politics , first foremost , social practice . 's still conversation , parties reduced monologue ."

# %%
wordcloud=WordCloud(stopwords=stopwords,width=1600,height=800,mask=mask,background_color='white')
wordcloud.generate(data)

plt.figure(figsize=(10,10),facecolor='k')
plt.axis("off")
plt.imshow(wordcloud)
plt.show()

# %% [markdown]
# # Word cloud 3

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from PIL import Image
import wikipedia

# %%
title=str(input("Enter the title: "))
keyword=wikipedia.search(title)
page=wikipedia.page(keyword)
content=page.content

stopwords=set(STOPWORDS)

mask=np.array(Image.open("C:\\Users\\vishal tupe\\Desktop\\data science practical\\Data Science\\world cloud\\761_twitter.jpg"))


wordcloud=WordCloud(background_color='white',max_words=300,stopwords=stopwords,mask=mask)
plt.figure(figsize=(10,10),facecolor="none")

wordcloud.generate(content)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# Enter the title: twitter
